# %% [markdown]
# <a href="https://colab.research.google.com/github/adamabednarek/ml-python/blob/master/43_polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports and constants
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sklearn

np.random.seed(42)
np.set_printoptions(precision=6, suppress=True)
sns.set(font_scale=1.3)

#Data generation
X = np.arange(-10,10,0.5)
noise = 80 * np.random.rand(40)
y = -X** 3 + 10*X**2 - 2*X + 3 + noise
X = X.reshape(40,1)

#Linear regression for the model
from sklearn.linear_model import LinearRegression

Regressor = LinearRegression()
Regressor = Regressor.fit(X,y)
Y_predicted_linear = np.ones(40)
for i in range(0,len(Predicted_linear)):
  Y_predicted_linear[i] = Regressor.intercept_ + Regressor.coef_ * X[i]

#Second degre regression for the model
from sklearn.preprocessing import PolynomialFeatures
df = pd.DataFrame(data={'X': X.ravel()})
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
df = pd.DataFrame(data=X_poly)
Regressor_poly = LinearRegression()
Regressor_poly = Regressor.fit(X_poly, y)
Y_predicted_poly = Regressor_poly.predict(X_poly)

#Third degre regression for the model
df2 = pd.DataFrame(data={'X': X.ravel()})
poly3 = PolynomialFeatures(degree=3)
X_poly3 = poly3.fit_transform(X)
df2 = pd.DataFrame(data=X_poly3)
Regressor_poly3 = LinearRegression()
Regressor_poly3 = Regressor.fit(X_poly3, y)
Y_predicted_poly3 = Regressor_poly3.predict(X_poly3)

#Presentation of score
from sklearn.metrics import r2_score
print(f'Score for the linear regression: {r2_score(y, Y_predicted_linear):.4f}')
print(f'Score for the polynomial regression(2): {r2_score(y, Y_predicted_poly):.4f}')
print(f'Score for the polynomial regression(3): {r2_score(y, Y_predicted_poly3):.4f}')

#Data presentation
plt.figure(figsize=(8,6))
plt.title('Polynomial regression')
plt.xlabel('X value')
plt.ylabel('Target value')
plt.scatter(X, y, label='X value', color='red')
plt.plot(X, Y_predicted_linear, label="Linear prediction", color="blue")
plt.plot(X, Y_predicted_poly, label="Polynomial(2) prediction", color="green")
plt.plot(X, Y_predicted_poly3, label="Polynomial(3) prediction", color="yellow")
plt.legend()
plt.show()
# Out:
# Score for the linear regression: 0.5391
# Score for the polynomial regression(2): 0.9158
# Score for the polynomial regression(3): 0.9981
